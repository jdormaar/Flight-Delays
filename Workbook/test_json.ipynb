# %% [markdown]
# ```py
# URL = "https://cdn.worldweatheronline.com/images/wsymbols01_png_64/"
# {
#     "data": {
#         "request": [
#             {
#                 "type": "LatLon",
#                 "query": "Lat 45.64 and Lon -122.66"
#             }
#         ],
#         "weather": [
#             {
#                 "date": "2020-12-24",
#                 "astronomy": [
#                     {
#                         "sunrise": "07:50 AM",
#                         "sunset": "04:31 PM",
#                         "moonrise": "01:33 PM",
#                         "moonset": "02:24 AM",
#                         "moon_phase": "First Quarter",
#                         "moon_illumination": "63"
#                     }
#                 ],
#                 "maxtempC": "7",
#                 "maxtempF": "44",
#                 "mintempC": "3",
#                 "mintempF": "38",
#                 "avgtempC": "5",
#                 "avgtempF": "41",
#                 "totalSnow_cm": "0.0",
#                 "sunHour": "6.9",
#                 "uvIndex": "3",
#                 "hourly": [
#                     {
#                         "time": "0",
#                         "tempC": "4",
#                         "tempF": "39",
#                         "windspeedMiles": "3",
#                         "windspeedKmph": "5",
#                         "winddirDegree": "55",
#                         "winddir16Point": "NE",
#                         "weatherCode": "113",
#                         "weatherIconUrl": [
#                             {
#                                 "value": f"{URL}wsymbol_0008_clear_sky_night.png"
#                             }
#                         ],
#                         "weatherDesc": [
#                             {
#                                 "value": "Clear"
#                             }
#                         ],
#                         "precipMM": "0.0",
#                         "precipInches": "0.0",
#                         "humidity": "78",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "pressure": "1025",
#                         "pressureInches": "30",
#                         "cloudcover": "0",
#                         "HeatIndexC": "4",
#                         "HeatIndexF": "39",
#                         "DewPointC": "1",
#                         "DewPointF": "33",
#                         "WindChillC": "3",
#                         "WindChillF": "38",
#                         "WindGustMiles": "4",
#                         "WindGustKmph": "6",
#                         "FeelsLikeC": "3",
#                         "FeelsLikeF": "38",
#                         "uvIndex": "1"
#                     },
#                     {
#                         "time": "300",
#                         "tempC": "4",
#                         "tempF": "39",
#                         "windspeedMiles": "2",
#                         "windspeedKmph": "4",
#                         "winddirDegree": "65",
#                         "winddir16Point": "ENE",
#                         "weatherCode": "113",
#                         "weatherIconUrl": [
#                             {
#                                 "value": f"{URL}wsymbol_0008_clear_sky_night.png"
#                             }
#                         ],
#                         "weatherDesc": [
#                             {
#                                 "value": "Clear"
#                             }
#                         ],
#                         "precipMM": "0.0",
#                         "precipInches": "0.0",
#                         "humidity": "77",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "pressure": "1024",
#                         "pressureInches": "30",
#                         "cloudcover": "0",
#                         "HeatIndexC": "4",
#                         "HeatIndexF": "39",
#                         "DewPointC": "0",
#                         "DewPointF": "33",
#                         "WindChillC": "4",
#                         "WindChillF": "39",
#                         "WindGustMiles": "2",
#                         "WindGustKmph": "4",
#                         "FeelsLikeC": "4",
#                         "FeelsLikeF": "39",
#                         "uvIndex": "1"
#                     },
#                     {
#                         "time": "600",
#                         "tempC": "3",
#                         "tempF": "38",
#                         "windspeedMiles": "2",
#                         "windspeedKmph": "3",
#                         "winddirDegree": "61",
#                         "winddir16Point": "ENE",
#                         "weatherCode": "113",
#                         "weatherIconUrl": [
#                             {
#                                 "value": f"{URL}wsymbol_0001_sunny.png"
#                             }
#                         ],
#                         "weatherDesc": [
#                             {
#                                 "value": "Sunny"
#                             }
#                         ],
#                         "precipMM": "0.0",
#                         "precipInches": "0.0",
#                         "humidity": "75",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "pressure": "1023",
#                         "pressureInches": "30",
#                         "cloudcover": "0",
#                         "HeatIndexC": "3",
#                         "HeatIndexF": "38",
#                         "DewPointC": "-1",
#                         "DewPointF": "31",
#                         "WindChillC": "3",
#                         "WindChillF": "38",
#                         "WindGustMiles": "2",
#                         "WindGustKmph": "4",
#                         "FeelsLikeC": "3",
#                         "FeelsLikeF": "38",
#                         "uvIndex": "2"
#                     },
#                     {
#                         "time": "900",
#                         "tempC": "4",
#                         "tempF": "39",
#                         "windspeedMiles": "2",
#                         "windspeedKmph": "4",
#                         "winddirDegree": "74",
#                         "winddir16Point": "ENE",
#                         "weatherCode": "113",
#                         "weatherIconUrl": [
#                             {
#                                 "value": f"{URL}wsymbol_0001_sunny.png"
#                             }
#                         ],
#                         "weatherDesc": [
#                             {
#                                 "value": "Sunny"
#                             }
#                         ],
#                         "precipMM": "0.0",
#                         "precipInches": "0.0",
#                         "humidity": "70",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "pressure": "1022",
#                         "pressureInches": "30",
#                         "cloudcover": "0",
#                         "HeatIndexC": "4",
#                         "HeatIndexF": "39",
#                         "DewPointC": "-1",
#                         "DewPointF": "30",
#                         "WindChillC": "4",
#                         "WindChillF": "38",
#                         "WindGustMiles": "2",
#                         "WindGustKmph": "4",
#                         "FeelsLikeC": "4",
#                         "FeelsLikeF": "38",
#                         "uvIndex": "2"
#                     },
#                     {
#                         "time": "1200",
#                         "tempC": "6",
#                         "tempF": "44",
#                         "windspeedMiles": "1",
#                         "windspeedKmph": "2",
#                         "winddirDegree": "79",
#                         "winddir16Point": "E",
#                         "weatherCode": "122",
#                         "weatherIconUrl": [
#                             {
#                                 "value": f"{URL}wsymbol_0004_black_low_cloud.png"
#                             }
#                         ],
#                         "weatherDesc": [
#                             {
#                                 "value": "Overcast"
#                             }
#                         ],
#                         "precipMM": "0.0",
#                         "precipInches": "0.0",
#                         "humidity": "59",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "pressure": "1021",
#                         "pressureInches": "30",
#                         "cloudcover": "33",
#                         "HeatIndexC": "6",
#                         "HeatIndexF": "44",
#                         "DewPointC": "-1",
#                         "DewPointF": "30",
#                         "WindChillC": "6",
#                         "WindChillF": "44",
#                         "WindGustMiles": "2",
#                         "WindGustKmph": "3",
#                         "FeelsLikeC": "6",
#                         "FeelsLikeF": "44",
#                         "uvIndex": "2"
#                     },
#                     {
#                         "time": "1500",
#                         "tempC": "7",
#                         "tempF": "44",
#                         "windspeedMiles": "1",
#                         "windspeedKmph": "2",
#                         "winddirDegree": "57",
#                         "winddir16Point": "ENE",
#                         "weatherCode": "122",
#                         "weatherIconUrl": [
#                             {
#                                 "value": f"{URL}wsymbol_0004_black_low_cloud.png"
#                             }
#                         ],
#                         "weatherDesc": [
#                             {
#                                 "value": "Overcast"
#                             }
#                         ],
#                         "precipMM": "0.0",
#                         "precipInches": "0.0",
#                         "humidity": "56",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "pressure": "1019",
#                         "pressureInches": "30",
#                         "cloudcover": "99",
#                         "HeatIndexC": "7",
#                         "HeatIndexF": "44",
#                         "DewPointC": "-1",
#                         "DewPointF": "30",
#                         "WindChillC": "7",
#                         "WindChillF": "44",
#                         "WindGustMiles": "2",
#                         "WindGustKmph": "3",
#                         "FeelsLikeC": "7",
#                         "FeelsLikeF": "44",
#                         "uvIndex": "2"
#                     },
#                     {
#                         "time": "1800",
#                         "tempC": "5",
#                         "tempF": "41",
#                         "windspeedMiles": "2",
#                         "windspeedKmph": "3",
#                         "winddirDegree": "54",
#                         "winddir16Point": "NE",
#                         "weatherCode": "116",
#                         "weatherIconUrl": [
#                             {
#                                 "value": f"{URL}wsymbol_0004_black_low_cloud.png"
#                             }
#                         ],
#                         "weatherDesc": [
#                             {
#                                 "value": "Partly cloudy"
#                             }
#                         ],
#                         "precipMM": "0.0",
#                         "precipInches": "0.0",
#                         "humidity": "64",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "pressure": "1018",
#                         "pressureInches": "30",
#                         "cloudcover": "76",
#                         "HeatIndexC": "5",
#                         "HeatIndexF": "41",
#                         "DewPointC": "-1",
#                         "DewPointF": "29",
#                         "WindChillC": "5",
#                         "WindChillF": "40",
#                         "WindGustMiles": "4",
#                         "WindGustKmph": "6",
#                         "FeelsLikeC": "5",
#                         "FeelsLikeF": "40",
#                         "uvIndex": "1"
#                     },
#                     {
#                         "time": "2100",
#                         "tempC": "4",
#                         "tempF": "39",
#                         "windspeedMiles": "3",
#                         "windspeedKmph": "4",
#                         "winddirDegree": "74",
#                         "winddir16Point": "ENE",
#                         "weatherCode": "116",
#                         "weatherIconUrl": [
#                             {
#                                 "value": f"{URL}wsymbol_0004_black_low_cloud.png"
#                             }
#                         ],
#                         "weatherDesc": [
#                             {
#                                 "value": "Partly cloudy"
#                             }
#                         ],
#                         "precipMM": "0.0",
#                         "precipInches": "0.0",
#                         "humidity": "66",
#                         "visibility": "10",
#                         "visibilityMiles": "6",
#                         "pressure": "1018",
#                         "pressureInches": "30",
#                         "cloudcover": "37",
#                         "HeatIndexC": "4",
#                         "HeatIndexF": "39",
#                         "DewPointC": "-2",
#                         "DewPointF": "29",
#                         "WindChillC": "3",
#                         "WindChillF": "38",
#                         "WindGustMiles": "4",
#                         "WindGustKmph": "7",
#                         "FeelsLikeC": "3",
#                         "FeelsLikeF": "38",
#                         "uvIndex": "1"
#                     }
#                 ]
#             }
#         ]
#     }
# }
# ```

# %%
URL = "https://cdn.worldweatheronline.com/images/wsymbols01_png_64/"
{
    "data": {
        "request": [
            {
                "type": "LatLon",
                "query": "Lat 45.64 and Lon -122.66"
            }
        ],
        "weather": [
            {
                "date": "2020-12-24",
                "astronomy": [
                    {
                        "sunrise": "07:50 AM",
                        "sunset": "04:31 PM",
                        "moonrise": "01:33 PM",
                        "moonset": "02:24 AM",
                        "moon_phase": "First Quarter",
                        "moon_illumination": "63"
                    }
                ],
                "maxtempC": "7",
                "maxtempF": "44",
                "mintempC": "3",
                "mintempF": "38",
                "avgtempC": "5",
                "avgtempF": "41",
                "totalSnow_cm": "0.0",
                "sunHour": "6.9",
                "uvIndex": "3",
                "hourly": [
                    {
                        "time": "0",
                        "tempC": "4",
                        "tempF": "39",
                        "windspeedMiles": "3",
                        "windspeedKmph": "5",
                        "winddirDegree": "55",
                        "winddir16Point": "NE",
                        "weatherCode": "113",
                        "weatherIconUrl": [
                            {
                                "value": f"{URL}wsymbol_0008_clear_sky_night.png"
                            }
                        ],
                        "weatherDesc": [
                            {
                                "value": "Clear"
                            }
                        ],
                        "precipMM": "0.0",
                        "precipInches": "0.0",
                        "humidity": "78",
                        "visibility": "10",
                        "visibilityMiles": "6",
                        "pressure": "1025",
                        "pressureInches": "30",
                        "cloudcover": "0",
                        "HeatIndexC": "4",
                        "HeatIndexF": "39",
                        "DewPointC": "1",
                        "DewPointF": "33",
                        "WindChillC": "3",
                        "WindChillF": "38",
                        "WindGustMiles": "4",
                        "WindGustKmph": "6",
                        "FeelsLikeC": "3",
                        "FeelsLikeF": "38",
                        "uvIndex": "1"
                    },
                    {
                        "time": "300",
                        "tempC": "4",
                        "tempF": "39",
                        "windspeedMiles": "2",
                        "windspeedKmph": "4",
                        "winddirDegree": "65",
                        "winddir16Point": "ENE",
                        "weatherCode": "113",
                        "weatherIconUrl": [
                            {
                                "value": f"{URL}wsymbol_0008_clear_sky_night.png"
                            }
                        ],
                        "weatherDesc": [
                            {
                                "value": "Clear"
                            }
                        ],
                        "precipMM": "0.0",
                        "precipInches": "0.0",
                        "humidity": "77",
                        "visibility": "10",
                        "visibilityMiles": "6",
                        "pressure": "1024",
                        "pressureInches": "30",
                        "cloudcover": "0",
                        "HeatIndexC": "4",
                        "HeatIndexF": "39",
                        "DewPointC": "0",
                        "DewPointF": "33",
                        "WindChillC": "4",
                        "WindChillF": "39",
                        "WindGustMiles": "2",
                        "WindGustKmph": "4",
                        "FeelsLikeC": "4",
                        "FeelsLikeF": "39",
                        "uvIndex": "1"
                    },
                    {
                        "time": "600",
                        "tempC": "3",
                        "tempF": "38",
                        "windspeedMiles": "2",
                        "windspeedKmph": "3",
                        "winddirDegree": "61",
                        "winddir16Point": "ENE",
                        "weatherCode": "113",
                        "weatherIconUrl": [
                            {
                                "value": f"{URL}wsymbol_0001_sunny.png"
                            }
                        ],
                        "weatherDesc": [
                            {
                                "value": "Sunny"
                            }
                        ],
                        "precipMM": "0.0",
                        "precipInches": "0.0",
                        "humidity": "75",
                        "visibility": "10",
                        "visibilityMiles": "6",
                        "pressure": "1023",
                        "pressureInches": "30",
                        "cloudcover": "0",
                        "HeatIndexC": "3",
                        "HeatIndexF": "38",
                        "DewPointC": "-1",
                        "DewPointF": "31",
                        "WindChillC": "3",
                        "WindChillF": "38",
                        "WindGustMiles": "2",
                        "WindGustKmph": "4",
                        "FeelsLikeC": "3",
                        "FeelsLikeF": "38",
                        "uvIndex": "2"
                    },
                    {
                        "time": "900",
                        "tempC": "4",
                        "tempF": "39",
                        "windspeedMiles": "2",
                        "windspeedKmph": "4",
                        "winddirDegree": "74",
                        "winddir16Point": "ENE",
                        "weatherCode": "113",
                        "weatherIconUrl": [
                            {
                                "value": f"{URL}wsymbol_0001_sunny.png"
                            }
                        ],
                        "weatherDesc": [
                            {
                                "value": "Sunny"
                            }
                        ],
                        "precipMM": "0.0",
                        "precipInches": "0.0",
                        "humidity": "70",
                        "visibility": "10",
                        "visibilityMiles": "6",
                        "pressure": "1022",
                        "pressureInches": "30",
                        "cloudcover": "0",
                        "HeatIndexC": "4",
                        "HeatIndexF": "39",
                        "DewPointC": "-1",
                        "DewPointF": "30",
                        "WindChillC": "4",
                        "WindChillF": "38",
                        "WindGustMiles": "2",
                        "WindGustKmph": "4",
                        "FeelsLikeC": "4",
                        "FeelsLikeF": "38",
                        "uvIndex": "2"
                    },
                    {
                        "time": "1200",
                        "tempC": "6",
                        "tempF": "44",
                        "windspeedMiles": "1",
                        "windspeedKmph": "2",
                        "winddirDegree": "79",
                        "winddir16Point": "E",
                        "weatherCode": "122",
                        "weatherIconUrl": [
                            {
                                "value": f"{URL}wsymbol_0004_black_low_cloud.png"
                            }
                        ],
                        "weatherDesc": [
                            {
                                "value": "Overcast"
                            }
                        ],
                        "precipMM": "0.0",
                        "precipInches": "0.0",
                        "humidity": "59",
                        "visibility": "10",
                        "visibilityMiles": "6",
                        "pressure": "1021",
                        "pressureInches": "30",
                        "cloudcover": "33",
                        "HeatIndexC": "6",
                        "HeatIndexF": "44",
                        "DewPointC": "-1",
                        "DewPointF": "30",
                        "WindChillC": "6",
                        "WindChillF": "44",
                        "WindGustMiles": "2",
                        "WindGustKmph": "3",
                        "FeelsLikeC": "6",
                        "FeelsLikeF": "44",
                        "uvIndex": "2"
                    },
                    {
                        "time": "1500",
                        "tempC": "7",
                        "tempF": "44",
                        "windspeedMiles": "1",
                        "windspeedKmph": "2",
                        "winddirDegree": "57",
                        "winddir16Point": "ENE",
                        "weatherCode": "122",
                        "weatherIconUrl": [
                            {
                                "value": f"{URL}wsymbol_0004_black_low_cloud.png"
                            }
                        ],
                        "weatherDesc": [
                            {
                                "value": "Overcast"
                            }
                        ],
                        "precipMM": "0.0",
                        "precipInches": "0.0",
                        "humidity": "56",
                        "visibility": "10",
                        "visibilityMiles": "6",
                        "pressure": "1019",
                        "pressureInches": "30",
                        "cloudcover": "99",
                        "HeatIndexC": "7",
                        "HeatIndexF": "44",
                        "DewPointC": "-1",
                        "DewPointF": "30",
                        "WindChillC": "7",
                        "WindChillF": "44",
                        "WindGustMiles": "2",
                        "WindGustKmph": "3",
                        "FeelsLikeC": "7",
                        "FeelsLikeF": "44",
                        "uvIndex": "2"
                    },
                    {
                        "time": "1800",
                        "tempC": "5",
                        "tempF": "41",
                        "windspeedMiles": "2",
                        "windspeedKmph": "3",
                        "winddirDegree": "54",
                        "winddir16Point": "NE",
                        "weatherCode": "116",
                        "weatherIconUrl": [
                            {
                                "value": f"{URL}wsymbol_0004_black_low_cloud.png"
                            }
                        ],
                        "weatherDesc": [
                            {
                                "value": "Partly cloudy"
                            }
                        ],
                        "precipMM": "0.0",
                        "precipInches": "0.0",
                        "humidity": "64",
                        "visibility": "10",
                        "visibilityMiles": "6",
                        "pressure": "1018",
                        "pressureInches": "30",
                        "cloudcover": "76",
                        "HeatIndexC": "5",
                        "HeatIndexF": "41",
                        "DewPointC": "-1",
                        "DewPointF": "29",
                        "WindChillC": "5",
                        "WindChillF": "40",
                        "WindGustMiles": "4",
                        "WindGustKmph": "6",
                        "FeelsLikeC": "5",
                        "FeelsLikeF": "40",
                        "uvIndex": "1"
                    },
                    {
                        "time": "2100",
                        "tempC": "4",
                        "tempF": "39",
                        "windspeedMiles": "3",
                        "windspeedKmph": "4",
                        "winddirDegree": "74",
                        "winddir16Point": "ENE",
                        "weatherCode": "116",
                        "weatherIconUrl": [
                            {
                                "value": f"{URL}wsymbol_0004_black_low_cloud.png"
                            }
                        ],
                        "weatherDesc": [
                            {
                                "value": "Partly cloudy"
                            }
                        ],
                        "precipMM": "0.0",
                        "precipInches": "0.0",
                        "humidity": "66",
                        "visibility": "10",
                        "visibilityMiles": "6",
                        "pressure": "1018",
                        "pressureInches": "30",
                        "cloudcover": "37",
                        "HeatIndexC": "4",
                        "HeatIndexF": "39",
                        "DewPointC": "-2",
                        "DewPointF": "29",
                        "WindChillC": "3",
                        "WindChillF": "38",
                        "WindGustMiles": "4",
                        "WindGustKmph": "7",
                        "FeelsLikeC": "3",
                        "FeelsLikeF": "38",
                        "uvIndex": "1"
                    }
                ]
            }
        ]
    }
}
